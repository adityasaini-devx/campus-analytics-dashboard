# %% [markdown]
# # 04. Model Training & Comparison - CampusPulse BIBenchmarking Logistic Regression, Random Forest, and Gradient Boosting against the Baseline Rule Model on stratified test data.

# %%
import pandas as pdimport numpy as npimport syssys.path.append('..')from src.train import train_and_evaluatebest_model, preprocessor, metrics = train_and_evaluate()

# %% [markdown]
# ## 1. Champion Model Performance Summary

# %%
print(f"Champion Model: {metrics['champion_model']}")print(pd.DataFrame(metrics['comparison']['models']).T)

# %% [markdown]
# ## 2. Key Takeaway on At-Risk RecallIn educational retention, False Negatives (missing an at-risk student) carry far higher cost than False Positives. Machine learning dramatically outclasses manual rule heuristics in Recall and F1.
